# %% [markdown]
# Solution by Marceli P

# %% [markdown]
# The Iris dataset contains the Iris flower dataset of Fisher. It is included in the attachment. The file's class label is the last column in the file.
# (Use the parameter skiprows = 1 to load the file)
#
# 1. On its basis, create a training and test set with parameter random_state = 0
# 2. With the help of the GridSearchCV function, find the best parameters for a logistic regression model from:
# "C": 0.001, 0.01, 0.1, 1.0, 10.0, 100.0,
# "penalty": 'l1', 'l2', 'elasticnet',
# "solver": 'lbfgs', 'liblinear', 'sag'
#
# (some parameters do not work together and you will be warned about this)
#
# 3. Enter the parameters of the best classifier.
# 4. Using a trained classifier, make a prediction on the test set and enter the average prediction accuracy.
# 5. Use StandardScaler () and normalize the dataset.
# 6. As in step 2, train a new classifier on the normalized data.
# 7. Using the second trained classifier, make a prediction on the test set and enter the average prediction accuracy.
# 8. Enter the parameters of the best, new classifier

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import average_precision_score

# %%
df = pd.read_csv('iris.csv', sep=',')

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width  variety
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
X = df.iloc[:, :3]
y = df.iloc[:, 4]
#print(X,y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
logreg = LogisticRegression()

grid_all = {"C": [0.001, 0.01, 0.1, 1.0, 10.0, 100.0],
            "penalty": ['l1', 'l2', 'elasticnet'],
            "solver": ['lbfgs', 'liblinear', 'sag']}




logreg_cv = GridSearchCV(logreg, grid_all, cv=10)
logreg_cv.fit(X_train,y_train)

print("Tuned hyperparameters :(the best parameters) " , logreg_cv.best_params_)
print("Best score :" , logreg_cv.best_score_)
# Out:
# C:\Users\Marceli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Marceli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Marceli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...

# %% [markdown]
# Tuned hyperparameters :(the best parameters)  {'C': 1.0, 'penalty': 'l2', 'solver': 'sag'}
#
# Best score : 0.9800000000000001

# %% [markdown]
# 4. Using a trained classifier, make a prediction on the test set and enter the average prediction accuracy.

# %%
y_true, y_pred = y_test, logreg_cv.predict(X_test)


print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       0.94      0.89      0.91        18
#            2       0.83      0.91      0.87        11
#
#     accuracy                           0.93        45
#    macro avg       0.92      0.93      0.93        45
# weighted avg       0.94      0.93      0.93        45

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import accuracy_score

print("Balanced accuracy score :", balanced_accuracy_score(y_true, y_pred))
print ("Average accuracy is: ", accuracy_score(y_true, y_pred) * 100, "%")
# Out:
# Balanced accuracy score : 0.9326599326599326
# Average accuracy is:  93.33333333333333 %

# %% [markdown]
# 5. Use StandardScaler () and normalize the dataset.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_x = scaler.fit_transform(X)

#print(scale_x)

# %% [markdown]
# 6. As in step 2, train a new classifier on the normalized data.

# %%
X_train, X_test, y_train, y_test = train_test_split(scaled_x, y, test_size=0.3, random_state=0)

logreg = LogisticRegression()

grid_all = {"C": [0.001, 0.01, 0.1, 1.0, 10.0, 100.0],
            "penalty": ['l1', 'l2', 'elasticnet'],
            "solver": ['lbfgs', 'liblinear', 'sag']}




logreg_cv = GridSearchCV(logreg, grid_all, cv=10)
logreg_cv.fit(X_train,y_train)

print("Tuned hyperparameters :(the best parameters) " , logreg_cv.best_params_)
print("Best score :" , logreg_cv.best_score_)
# Out:
# Tuned hyperparameters :(the best parameters)  {'C': 10.0, 'penalty': 'l2', 'solver': 'lbfgs'}
# Best score : 0.9700000000000001
# C:\Users\Marceli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Marceli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Marceli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...

# %% [markdown]
# Previous:
#
# * Tuned hyperparameters :(the best parameters)  {'C': 1.0, 'penalty': 'l2', 'solver': 'sag'}
# * Accuracy : 0.9800000000000001
#
#
#
#
# With normalized dataset:
#
# * Tuned hyperparameters :(the best parameters)  {'C': 10.0, 'penalty': 'l2', 'solver': 'lbfgs'}
# * Accuracy : 0.9700000000000001

# %%
from sklearn.metrics import balanced_accuracy_score

y_true, y_pred = y_test, logreg_cv.predict(X_test)
print("Balanced accuracy score :", balanced_accuracy_score(y_true, y_pred))
print ("Average accuracy is: ", accuracy_score(y_true, y_pred) * 100, "%")
# Out:
# Balanced accuracy score : 0.9208754208754208
# Average accuracy is:  93.33333333333333 %

# %% [markdown]
# Results without a normalized dataset have better predictions by about 1‰
